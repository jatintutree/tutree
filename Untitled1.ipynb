# %%
import pandas as pd

# %%
data = pd.read_csv("C://Users/CPS/Documents/leads_gender/30SepLeads.csv")
#data2 = pd.read_csv("C://Users/CPS/Documents/leads_gender/13AugLeads1.csv")

# %%
data.shape[0]
# Out:
# 35956

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35956 entries, 0 to 35955
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          35956 non-null  object
#  1   phone_number  35956 non-null  int64
#  2   age           35956 non-null  int64
#  3   city          35543 non-null  object
#  4   state         35543 non-null  object
#  5   zipcode       35543 non-null  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.6+ MB

# %%
data.name.isnull().sum()
# Out:
# 0

# %%
df = data.dropna(subset=['phone_number', 'name'], how='all')

# %%
data.columns
# Out:
# Index(['name', 'phone_number', 'age', 'city', 'state', 'zipcode'], dtype='object')

# %%
df.shape
# Out:
# (5411, 6)

# %%
df = data.dropna(subset=['phone_number', 'name'])

# %%
df.shape
# Out:
# (35636, 7)

# %%
df.head(20)
# Out:
#     phone_number                         email               name  age  \
# 0     2036192069                           NaN   Julianna Palumbo   25
# 1     2406261268                           NaN   Valeria Martinez   25
# 2     3392360565                           NaN    Lauren Boudreau   25
# 4     2252476871                           NaN       Jaylen Jones   25
# 7     6104062720         omarachanel@gmail.com       Chanel omara   25
# 8     7042222133        vpowens11584@yahoo.com      Reggie  Owens   25
# 9     3195725832                           NaN     Rianni Rodgers   25
# 10    7202555135                           NaN        Mason Haupt   25
# 11    7132045331  martinez.antoniouh@gmail.com   Antonio Martinez   25
# 12    5095600047                           NaN     Narya  Naillon   25
# 14    5092175576                           NaN   Dominick Neumann   25
# 15    6098286597                           NaN       Tyler Watson   25
# ...

# %%
pip install gender-guesser
# Out:
# ...
#    ---------------------------------------- 0.0/379.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/379.3 kB ? eta -:--:--
#    -------------------- ------------------- 194.6/379.3 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 379.3/379.3 kB 3.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gender_guesser.detector as gender
from nameparser import HumanName as hn
# Initialize the gender detector
d = gender.Detector(case_sensitive=True)

# Function to predict gender based on first name
def predict_gender(name):
    name = hn(name)
    first_name = name.first # Get the first name
    return d.get_gender(first_name)

# Apply the function to the 'name' column
data['gender'] = data['name'].apply(predict_gender)


def classify(data):
    female_data = data[data['gender'].isin(['female', 'mostly_female', 'unknown'])]
    male_data = data[data['gender'].isin(['male', 'mostly_male'])]

    # Dropping the 'gender' column in both dataframes
    male_data = male_data.drop('gender', axis=1)
    female_data = female_data.drop('gender', axis=1)

    # Printing the counts
    print(f"females :\t{female_data.shape[0]} \nmales :\t{male_data.shape[0]}")
    #female_data.to_csv(f"C://Users/CPS/Documents/cleaned_leads_female/leads_{pd.Timestamp.now().date()}.csv")
    male_data.to_csv(f"C://Users/CPS/Documents/cleaned_leads_male/leads_{pd.Timestamp.now().date()}.csv")
    return female_data, male_data 

# Assuming 'data' is your pandas DataFrame
# Call the function with your data
female_data, male_data = classify(data)
# Out:
# females :	21742
# males :	13872

# %%
female_data.head()
# Out:
#                     name  phone_number  age           city state  zipcode
# 35949    Jamie L Weekley    5735614632   45  Fredericktown    MO  63645.0
# 35950   Olga A Salnikova    5038884379   45       Portland    OR  97223.0
# 35952  Shannon Henderson    7542379143   45     B Lagrange    GA  30240.0
# 35954       Kami J Brown    3609533995   45          Camas    WA  98607.0
# 35955    Cheriee S Brown    5302191379   45        Visalia    CA  93292.0

# %%
data = pd.read_csv("C://Users/CPS/Documents/cleaned_leads_female/leads_2024-08-08.csv")
data.shape[0]
# Out:
# 830

# %%
data = pd.read_csv("C://Users/CPS/Documents/cleaned_leads_female/backup_data/leads2_2024-08-13.csv")
merged_df = pd.concat([data, female_data], ignore_index=True)
merged_df.shape
# Out:
# (9402, 6)

# %%
merged_df1 = female_data[0:2500]
merged_df1.to_csv(f"C://Users/CPS/Documents/cleaned_leads_female/leads1_{pd.Timestamp.now().date()}.csv")
merged_df2 = female_data[2500:5000]
merged_df2.to_csv(f"C://Users/CPS/Documents/cleaned_leads_female/leads2_{pd.Timestamp.now().date()}.csv")
merged_df3 = female_data[5000:7500]
merged_df3.to_csv(f"C://Users/CPS/Documents/cleaned_leads_female/leads3_{pd.Timestamp.now().date()}.csv")
merged_df4 = female_data[7500:10000]
merged_df4.to_csv(f"C://Users/CPS/Documents/cleaned_leads_female/leads4_{pd.Timestamp.now().date()}.csv")
merged_df5 = female_data[10000:12500]
merged_df5.to_csv(f"C://Users/CPS/Documents/cleaned_leads_female/leads5_{pd.Timestamp.now().date()}.csv")
merged_df6 = female_data[12500:15000]
merged_df6.to_csv(f"C://Users/CPS/Documents/cleaned_leads_female/leads6_{pd.Timestamp.now().date()}.csv")
merged_df7 = female_data[15000:17500]
merged_df7.to_csv(f"C://Users/CPS/Documents/cleaned_leads_female/leads7_{pd.Timestamp.now().date()}.csv")
merged_df8 = female_data[17500:]
merged_df8.to_csv(f"C://Users/CPS/Documents/cleaned_leads_female/leads8_{pd.Timestamp.now().date()}.csv")

# %%
import pandas as pd

# Define the chunk size and the directory to save the files
chunk_size = 1200
save_directory = "C://Users/CPS/Documents/cleaned_leads_female/backup_data/"

# Loop through the DataFrame in chunks and save each chunk as a separate CSV file
for i in range(0, len(female_data), chunk_size):
    chunk = female_data[i:i+chunk_size]
    chunk_number = (i // chunk_size) + 1
    chunk.to_csv(f"{save_directory}leads{chunk_number}_{pd.Timestamp.now().date()}.csv", index=False)

# %%
merged_df[7500:].to_csv(f"C://Users/CPS/Documents/cleaned_leads_female/backup_data/leads_{pd.Timestamp.now().date()}.csv")

# %%
male_data.to_csv("C://Users/CPS/Documents/cleaned_leads_male/leads_30_july.csv")

# %%
import matplotlib.pyplot as plt
gender_counts = data['gender'].value_counts()
gender_counts.plot(kind='bar')
plt.show()

# %%
male_data = data[(data['gender'] == 'male') | (data['gender'] == 'mostly_male')]
male_data.shape
# Out:
# (785, 7)

# %%
def classify():
    female_data = data[(data['gender'] == 'female') | (data['gender'] == 'mostly_female') | (data['gender'] == 'unknown')]
    male_data = data[(data['gender'] == 'male') | (data['gender'] == 'mostly_male')]
    male_data.drop('gender',axis=1, inplace=True)
    female_data.drop('gender', axis = 1, inplace=True)
    print(f"females :\t{female_data.shape[0]} \n males :\t{male_data.shape[0]}")

classify()
# Out:
# females :	1106
#  males :	493
# C:\Users\CPS\AppData\Local\Temp\ipykernel_5612\579035561.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_data.drop('gender', axis = 1, inplace=True)

# %%
male_data1 = male_data[0:1500]
male_data1.to_csv("C://Users/CPS/Documents/cleaned_leads_male/leads_23_july.csv")
male_data2 = male_data[1500:3000]
male_data2.to_csv("C://Users/CPS/Documents/cleaned_leads_male/leads_24_july.csv")
male_data3 = male_data[3000:4500]
male_data3.to_csv("C://Users/CPS/Documents/cleaned_leads_male/leads_25_july.csv")
male_data4 = male_data[4500:6460]
male_data4.to_csv("C://Users/CPS/Documents/cleaned_leads_male/leads_26_july.csv")

print(f"male_data1: {male_data1.shape}\nmale_data2: {male_data2.shape}\nmale_data3: {male_data3.shape}\nmale_data4: {male_data4.shape}")
# Out:
# male_data1: (1500, 6)
# male_data2: (1500, 6)
# male_data3: (1500, 6)
# male_data4: (1960, 6)

# %%
female_data.head(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 female_data.head(4)
#
# NameError: name 'female_data' is not defined

# %%
import seaborn as sb

# %%
sb.pairplot(female_data)
# Out:
# C:\Users\CPS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CPS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CPS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Function to predict gender based on first name (limited to male and female only)
def predict_gender(name):
    name = hn(name)
    first_name = name.first  # Get the first name
    predicted_gender = d.get_gender(first_name)  # Get the predicted gender

    if predicted_gender == "male" or predicted_gender == "female":
        return predicted_gender
    else:
        return "unknown"  # Return "unknown" for any other predictions

data['gender'] = data['name'].apply(predict_gender)

# %%
import pandas as pd

current_date = pd.Timestamp.now().date()
print(current_date)
# Out:
# 2024-08-05

# %%
data1 = pd.read_csv("C://Users/CPS/Documents/leads_gender/12AugLeads.csv")
data2 = pd.read_csv("C://Users/CPS/Documents/leads_gender/09AugLeads.csv")
data = pd.concat([data1, data2], ignore_index=True)
data.shape
# Out:
# (1979, 6)

# %%
female_data.tail(2)
# Out:
#                     name  phone_number  age     city state  zipcode
# 32843     Mary E O'Neill    5622122185   45  Lahaina    HI  96761.0
# 32844  McDaniel R Hopson    7737095908   45     Gary    IN  46407.0

# %%
public_school = pd.read_csv("C://Users/CPS/Desktop/Public_Schools.csv")
private_school = pd.read_csv("C://Users/CPS/Desktop/Private_Schools.csv")
#merged_df = pd.concat([data, female_data], ignore_index=True)
#merged_df.shape

# %%
print(f"columns on public school data\n{public_school.columns}\nnumber of rows\t{public_school.shape[0]}")
# Out:
# columns on public school data
# Index(['NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'ZIP4', 'TELEPHONE', 'TYPE',
#        'STATUS', 'POPULATION', 'COUNTY', 'COUNTYFIPS', 'COUNTRY', 'NAICS_CODE',
#        'NAICS_DESC', 'WEBSITE', 'LEVEL_', 'ENROLLMENT', 'ST_GRADE',
#        'END_GRADE', 'DISTRICTID', 'FT_TEACHER', 'SHELTER_ID'],
#       dtype='object')
# number of rows	102334

# %%
sample_data_school = public_school[0:20]

# %%
sample_data_school.to_csv("C://Users/CPS/Desktop/sample_public_Schools.csv")
